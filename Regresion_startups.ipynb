# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import statsmodels
import sklearn.linear_model as lm

data=pd.read_csv("C:/Users/marti/OneDrive/Documentos/personal/Universidad/Econometria/ProblemSets/50_Startups.csv")#constituents-finantial.csv")
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
sns.boxplot(x="State",y="Profit",data=data)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %%
sns.heatmap(data.corr(),cmap="Blues")
data.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
#Seaborn plot por grupo de estado
plt.close()
sns.set_style("whitegrid")
sns.pairplot(data,hue="State",height=3)
plt.show()

# %%
x = data['R&D Spend']
y = data['Profit']
fig, ax = plt.subplots(figsize=(14, 7))
ax.scatter(x , y )
plt.xlabel('R&D Spend')
plt.ylabel('Profit')
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.show()
